# %% [markdown]
# s1= "100"
# print(type(s1))
# a1=int(s1)
# print(type(a1))
# f=1.5
# a1=intf
# print(type(a1))
# print(a1)

# %%
s1= "100"
print(type(s1))
a1=int(s1)
print(type(a1))
f=1.5
a1=int(f)
print(type(a1))
print(a1)
# Out:
# <class 'str'>
# <class 'int'>
# <class 'int'>
# 1

# %%
a1=1234
print(len(str(a1)))
# Out:
# 4

# %%
s1=input("enter the name")
print(s1)
print(type(s1))
# Out:
# enter the names.divya chandana
# s.divya chandana
# <class 'str'>

# %%
n1=int(input("enter a number"))
print(n1,type(n1))
# Out:
# enter a number2
# 2 <class 'int'>

# %%
n1=1234
print(n1+10)
print(n1-10)
print(n1*10)
print(n1/10)
print(n1%10)
print(n1**10)
print(n1//10)
# Out:
# 1244
# 1224
# 12340
# 123.4
# 4
# 8187505353567209228244052427776
# 123

# %%
x=1+2**3/4+5
print(x)
# Out:
# 8.0

# %%
x=1+2**3/4*5
print(x)
# Out:
# 11.0

# %%
x=10
a1=x>15
print(a1)
# Out:
# False

# %%
i=100
a1=(i>15) and (i<800)
a2=(i>15) and (i>800)
print(a1)
print(a2)
# Out:
# True
# False

# %%
n=int(input("enter a number"))
if n%2==0:
   print("even")
else:
      print("odd")
# Out:
# enter a number25
# odd

# %%
#check whether a number is perfectly multiple of 3 and 5
n=int(input("enter a number"))
if n%3==0 and n%5==0:
   print("yes")
else:
    print("no")
# Out:
# enter a number4
# no

# %%
# given number is positive,negative or zero
n=int(input("enter a number"))
if n==0:
  print("zero")
elif n>0:
  print("number is positive")
elif n<0:
  print("number is negative")
# Out:
# enter a number24
# number is positive
